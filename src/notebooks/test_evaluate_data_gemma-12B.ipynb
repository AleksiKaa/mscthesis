# %%
import os
import sys

# Set environment variables before importing transformers
os.environ["HUGGINGFACE_HUB_CACHE"] = "/scratch/shareddata/dldata/huggingface-hub-cache/hub" # Load local models
os.environ["TRANSFORMERS_OFFLINE"] = "1" 
os.environ["HF_HUB_OFFLINE"] = "1"
os.environ["HF_HOME"] = f"{os.environ["WRKDIR"]}/.cache/huggingface" # Cache in work directory

sys.path.append(
    os.path.abspath(os.path.join(os.getcwd(), ".."))
)  # Add parent directory to path

import argparse
import json
import pandas as pd
import transformers
from datasets import Dataset

from utils.prompts import (
    JUDGE_SYSTEM_PROMPT,
    JUDGE_TEMPLATE,
    GENERATE_EXERCISES_SYSTEM_PROMPT,
    GENERATE_EXERCISES_TEMPLATE_EXPLICIT,
    GENERATE_EXERCISES_TEMPLATE_FEWSHOT,
    GENERATE_EXERCISES_TEMPLATE_IMPLICIT,
    GENERATE_EXERCISES_TEMPLATE_ZEROSHOT,
)

# %%
DEFAULT_DATA = r"../../data/complete_dataset.csv"
DEFAULT_MODEL = "google/gemma-3-12b-it"

system_prompts = {
    "judge": JUDGE_SYSTEM_PROMPT,
    "zeroshot": GENERATE_EXERCISES_SYSTEM_PROMPT,
    "fewshot": GENERATE_EXERCISES_SYSTEM_PROMPT,
    "explicit": GENERATE_EXERCISES_SYSTEM_PROMPT,
    "implicit": GENERATE_EXERCISES_SYSTEM_PROMPT,
}

# %%
def make_prompt(row, task_type):
    _, problem_description, example_solution, _, _, theme, topic, concept, *_ = row

    match task_type:
        case "judge":
                return (JUDGE_TEMPLATE.replace("$THEME$", theme)
                .replace("$TOPIC$", topic)
                .replace("$CONCEPT$", concept)
                .replace("$TEXT$", problem_description)
                .replace("$CODE$", example_solution)
            )
        case "zeroshot":
            return GENERATE_EXERCISES_TEMPLATE_ZEROSHOT
        case "fewshot":
            return GENERATE_EXERCISES_TEMPLATE_FEWSHOT
        case "explicit":
            return GENERATE_EXERCISES_TEMPLATE_EXPLICIT
        case "implicit":
            return GENERATE_EXERCISES_TEMPLATE_IMPLICIT
        case _:
            raise ValueError(f"Task type '{_}' not recognised as valid task type!")


def run_model(pipe, data, task_type):
    system_prompt = system_prompts.get(task_type, None)

    if system_prompt is None:
        raise ValueError(f"Task type '{task_type}' not recognised as valid task type!")

    response = pipe(
        [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": data["prompt"]},
        ],
        return_full_text=False,
        max_new_tokens=500,
    )

    result = response[0]["generated_text" ]
    result = result.replace("```json", "").replace("```", "")
    
    result_dict = json.loads(result)

    for k, v in result_dict.items():
        data[k] = v

    return data

# %%
task = "judge"

# %%
params = {
    "model": DEFAULT_MODEL,
    "device_map": 0,  # Force GPU
    "max_new_tokens": 500,
    "temperature": 0.3,
}

pipeline = transformers.pipeline("text-generation", **params)
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
df = pd.read_csv(DEFAULT_DATA, sep=";")
n_rows = 3

eval_df = df
#eval_df = df.loc[0:n_rows - 1]
eval_df["prompt"] = eval_df.apply(lambda row: make_prompt(row, task), axis=1)

# %%
columns = df.columns
#print(columns)

eval_df = eval_df[eval_df[columns[11]] == "no"] # The exercise description does not match selected theme

eval_df
# Out:
#                          title  \
# 83              Berry Picking!
# 121           Pass the Parcel!
# 158           Pass the Parcel!
# 220  Holiday Parade Attendance
#
#                                     problemDescription  \
# 83   Write a program that asks the user for their f...
# 121  Write a program that asks the user for their n...
# 158  Write a program that asks the user for their n...
# 220  Write a program that asks the user if they wil...
#
#                                        exampleSolution  \
# 83   {'code': "import 'dart:io';main() {  print('Wh...
# 121  {'code': "import 'dart:io';main() {  print('Wh...
# 158  {'code': "import 'dart:io';main() {  print('Wh...
# 220  {'code': "import 'dart:io';  main() {   print(...
#
#                                     starterCode  \
# 83       {'code': "import 'dart:io';main() {}"}
# 121      {'code': "import 'dart:io';main() {}"}
# 158      {'code': "import 'dart:io';main() {}"}
# 220  {'code': "import 'dart:io';  main() {  }"}
#
#                                                  tests               theme  \
# 83   {'testCode': "import 'package:test/test.dart';...  outdoor activities
# 121  {'testCode': "import 'package:test/test.dart';...         party games
# 158  {'testCode': "import 'package:test/test.dart';...         party games
# 220  {'testCode': "import 'package:test/test.dart';...           Christmas
#
#                          topic         concept difficulty            id  \
# 83               berry picking      user input     normal  3.688261e+14
# 121            Pass the Parcel      user input   advanced  9.796044e+14
# 158            Pass the Parcel  program output     normal  6.068320e+14
# 220  attending holiday parades  program output     normal -8.374976e+13
#
#     The exercise description was clear (Yes/Partially/No)  \
# 83                                                 yes
# 121                                                yes
# 158                                                yes
# 220                                                yes
#
#     The exercise description matched the selected theme (Yes/Partially/No)  \
# 83                                                  no
# 121                                                 no
# 158                                                 no
# 220                                                 no
#
#     The exercise description matched the selected topic (Yes/Partially/No)  \
# 83                                                  no
# 121                                                 no
# 158                                                yes
# 220                                                yes
#
#     The exercise description matched the selected concept (Yes/No)  \
# 83                                                 yes
# 121                                                yes
# 158                                                yes
# 220                                                yes
#
#     Included concepts that were too advanced (Yes/No)\n  \
# 83                                                  no
# 121                                                 no
# 158                                                 no
# 220                                                yes
#
#     The exercise difficulty matched the selected difficulty (Too easy/Okay/Too difficult)  \
# 83                                                okay
# 121                                           too easy
# 158                                      too difficult
# 220                                      too difficult
#
#     Shallow vs deep personalization (Deep/Shallow/Unsure) Open field   \
# 83                                             shallow            NaN
# 121                                            shallow            NaN
# 158                                             unsure            NaN
# 220                                             unsure            NaN
#
#                                                 prompt
# 83   You are evaluating a programming exercise.\n\n...
# 121  You are evaluating a programming exercise.\n\n...
# 158  You are evaluating a programming exercise.\n\n...
# 220  You are evaluating a programming exercise.\n\n...

# %%
result = eval_df.apply(lambda row: run_model(pipeline, row, task), axis=1)
print("Done")
# Out:
# Done

# %%
for idx, row in result.iterrows():
    print("Theme: ", row["ThemeCorrect"])
    print("Topic: ", row["TopicCorrect"])
    print("Concept: ", row["ConceptCorrect"])
    print("Reasoning: ", row["Explanation"])
    print("")
# Out:
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  The exercise aligns perfectly with the intended theme (outdoor activities - berry picking) and topic (berry picking). It directly asks the user about their favorite berry, which fits the theme well. The core programming concept being taught is user input – specifically, getting input from the user using `stdin.readLineSync()`. The example solution demonstrates this concept effectively. The exercise is clear, concise, and appropriate for introductory programming students.
#
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  Let's break this down.
#
# **Step 1: What's the exercise about?** The exercise is about getting information (name and favorite color) from the user and then using that information to create a personalized greeting.
#
# **Step 2: Theme (Party Games):** The theme is 'party games'. While this exercise isn't a full-blown party game, it's a simple interaction that *could* be part of a larger game. Asking for names and preferences is common in party settings. So, it fits the theme reasonably well.
#
# **Step 3: Topic (Pass the Parcel):** The topic is 'Pass the Parcel'. This is a bit of a stretch. The exercise itself doesn't directly relate to the mechanics of Pass the Parcel. However, you could imagine this being a small part of a Pass the Parcel game – perhaps asking for a name before a round or a color to represent a team. It's not a perfect fit, but it's not entirely unrelated either.
#
# **Step 4: Concept (User Input):** This is where the exercise shines. It directly addresses the concept of user input. The program uses `stdin.readLineSync()` to get input from the user, stores it in variables, and then uses those variables later. This is a fundamental programming concept.
#
# **Final Evaluation:** Overall, the exercise is well-aligned with the user input concept. The theme and topic connections are weaker, but still plausible. It's a good introductory exercise for beginners to learn about getting input from the user.
#
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  Let's break this down.
#
# **Step 1: What's the exercise about?** The exercise is about getting input from the user (their name and favorite color) and then using that input to create a personalized message. It's a simple input/output task.
#
# **Step 2: Theme (Party Games)?** The theme is 'party games,' and the scenario of a 'pass the parcel' fits nicely. It's a playful, lighthearted context, which aligns well with the theme. So, the theme is correct.
#
# **Step 3: Topic (Pass the Parcel)?** The exercise directly references a pass the parcel, describing a parcel wrapped in the user's favorite color. This clearly relates to the topic. So, the topic is correct.
#
# **Step 4: Concept (Program Output)?** The core of the exercise is generating output based on user input. The program takes information, processes it (in a very simple way), and then produces a message. This perfectly demonstrates the concept of program output. So, the concept is correct.
#
# **Final Explanation:** The exercise is well-aligned with all three aspects: the theme of party games, the specific topic of pass the parcel, and the programming concept of program output. It's a good introductory exercise for beginners because it's straightforward and relatable.
#
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  The exercise aligns well with the intended theme of Christmas and the topic of attending holiday parades. The core programming concept being taught is program output – specifically, how to use conditional statements (if/else) to produce different outputs based on user input. The example solution provided demonstrates this concept accurately. The exercise is simple and appropriate for programming novices, focusing on basic input/output and conditional logic. The prompt is clear, and the expected output is well-defined.
