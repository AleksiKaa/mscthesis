# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

os.chdir("/home/kaariaa3/mscthesis/")
sys.path.append("./src/")  # Add module directory to path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from utils.plots import calculate_accuracy, plot_confusion_matrices, plot_distributions, plot_accuracy, plot_metric_heatmap, plot_precision_recall_curves, plot_cooccurrence, plot_error_distribution, GT_COLS, PRED_COLS, LABELS

# %%
csvs = [
    "./outputs/results/batch_16760089_result.csv", # Generated without explanation output
    "./outputs/results/batch_16760618_result.csv" # Generated with explanation output
]

# %%
df0 = pd.read_csv(csvs[1], sep=";")

calculate_accuracy(df0) # Dataframe contains gt and preds
# Out:
# {'theme_accuracy': np.float64(0.7514018691588785),
#  'topic_accuracy': np.float64(0.7813084112149533),
#  'concept_accuracy': np.float64(0.3813084112149533),
#  'total_accuracy': np.float64(0.33457943925233646)}

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 3))
plot_confusion_matrices(df0, axes)
plt.show()

# %%
fig, axes = plt.subplots(1, figsize=(15, 3))
plot_metric_heatmap(df0, axes)
plt.show()

# %%
fig, axes = plt.subplots(1, figsize=(6, 6))
plot_precision_recall_curves(df0, axes)
plt.show()

# %%
fig, axes = plt.subplots(1, figsize=(7, 6))
plot_cooccurrence(df0, axes)
plt.show()

# %%
fig, axes = plt.subplots(1, figsize=(6, 6))
plot_error_distribution(df0, axes)
plt.show()
