# %%
import os
import sys
import json

os.chdir("/home/kaariaa3/mscthesis/")
sys.path.append("./src/")  # Add module directory to path

import transformers
import pandas as pd

from utils.stats import calculate_accuracy

# %%
csvs = [
    "./outputs/results/batch_16760089_result.csv", # Generated without explanation output
    "./outputs/results/batch_16760118_result.csv" # Generated without explanation output
]

# %%
df1 = pd.read_csv(csvs[0], sep=";")

calculate_accuracy(df1) # Dataframe contains gt and preds
# Out:
# {'theme_accuracy': np.float64(0.7663551401869159),
#  'topic_accuracy': np.float64(0.7962616822429907),
#  'concept_accuracy': np.float64(0.6242990654205608),
#  'total_accuracy': np.float64(0.44485981308411215)}
