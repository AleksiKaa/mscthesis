# %%
import pandas as pd
# Out:
#                                                 title  \
# 0                                   Wildlife Spotting
# 1                                  Freeze Dance Game!
# 2                                     Rye Bread Order
# 3                                    Tower of London!
# 4                                      Holiday Movies
# 5                                    Christmas Carol!
# 6                                        Skiing Trip!
# 7                                   Grand Canal Tour!
# 8                                      Treasure Hunt!
# 9                                 Canoeing Adventure!
# 10                                    Cloudberry Jam!
# 11    Calculating the age of Looney Tunes characters.
# 12                         Biathlon Score Calculation
# 13  Calculate the distance between two points in P...
# 14                       Powerpuff Girls' Superpowers
# 15  Calculate the distance to Repovesi National Park.
# 16                         Bugs Bunny's carrot count.
# 17                              Jetsons' family ages.
# 18                  Calculate Leonardo da Vinci's Age
# 19         Calculate the average age of your lizards.
# 20  Calculate the age difference between Justin Bi...
# 21     Calculate the total cost of painting supplies.
# 22                         Taylor Swift Album Ratings
# 23                            Michelangelo's Artworks
# 24                              Taylor Swift's Albums
# 25                                     Guinea Pig Age
# 26                              Snake Length Category
# 27                                 Dali's Art Periods
# 28                             Fortnite Points System
# 29                      Snowboarding difficulty level
# 30                               Super Mario Power Up
# 31                                 Macrame Knot Types
# 32                         Pottery Quality Assessment
#
#    The exercise description matched the selected theme (Yes/Partially/No)  \
# 0                                                 yes
# 1                                                 yes
# 2                                                 yes
# 3                                                 yes
# 4                                                  no
# 5                                                 yes
# 6                                                 yes
# 7                                                 yes
# 8                                                 yes
# 9                                                 yes
# 10                                                yes
# 11                                                yes
# 12                                                yes
# 13                                                yes
# 14                                                yes
# 15                                                yes
# 16                                                yes
# 17                                                yes
# 18                                                yes
# 19                                                yes
# 20                                                yes
# 21                                                yes
# 22                                                yes
# 23                                                yes
# 24                                                yes
# 25                                                yes
# 26                                                yes
# 27                                                yes
# 28                                                yes
# 29                                                yes
# 30                                                yes
# 31                                                yes
# 32                                                 no
#
#    The exercise description matched the selected topic (Yes/Partially/No)  \
# 0                                                 yes
# 1                                                 yes
# 2                                                 yes
# 3                                                  no
# 4                                                 yes
# 5                                                 yes
# 6                                                 yes
# 7                                                 yes
# 8                                                 yes
# 9                                                 yes
# 10                                                yes
# 11                                                 no
# 12                                                yes
# 13                                                 no
# 14                                                yes
# 15                                                 no
# 16                                                yes
# 17                                                yes
# 18                                                yes
# 19                                                yes
# 20                                                yes
# 21                                                yes
# 22                                                yes
# 23                                                yes
# 24                                                yes
# 25                                                yes
# 26                                                yes
# 27                                                yes
# 28                                                yes
# 29                                                yes
# 30                                                yes
# 31                                                yes
# 32                                                 no
#
#    The exercise description matched the selected concept (Yes/No)  \
# 0                                                 yes
# 1                                                 yes
# 2                                                 yes
# 3                                                 yes
# 4                                                 yes
# 5                                                 yes
# 6                                                 yes
# 7                                                 yes
# 8                                                 yes
# 9                                                 yes
# 10                                                yes
# 11                                                yes
# 12                                                yes
# 13                                                yes
# 14                                                yes
# 15                                                yes
# 16                                                yes
# 17                                                yes
# 18                                                yes
# 19                                                yes
# 20                                                yes
# 21                                                yes
# 22                                                yes
# 23                                                yes
# 24                                                 no
# 25                                                yes
# 26                                                yes
# 27                                                yes
# 28                                                 no
# 29                                                yes
# 30                                                yes
# 31                                                 no
# 32                                                 no
#
#    All metrics are correct (Yes/No)
# 0                               yes
# 1                               yes
# 2                               yes
# 3                                no
# 4                                no
# 5                               yes
# 6                               yes
# 7                               yes
# 8                               yes
# 9                               yes
# 10                              yes
# 11                               no
# 12                              yes
# 13                               no
# 14                              yes
# 15                               no
# 16                              yes
# 17                              yes
# 18                              yes
# 19                              yes
# 20                              yes
# 21                              yes
# 22                              yes
# 23                              yes
# 24                               no
# 25                              yes
# 26                              yes
# 27                              yes
# 28                               no
# 29                              yes
# 30                              yes
# 31                               no
# 32                               no

# %%
filepath = "../../data/labels.csv"

df = pd.read_csv(filepath, sep=";")
df.columns = ["Title", "Theme matching", "Topic matching", "Concept matching", "All matching"]


print(
    df.head().to_latex(index=False)
    .replace("tabular}", "tabularx}{\\textwidth}", 1)
    .replace("tabular}", "tabularx}")
)
# Out:
# \begin{tabularx}{\textwidth}{lllll}
# \toprule
# Title & Theme matching & Topic matching & Concept matching & All matching \\
# \midrule
# Wildlife Spotting & yes & yes & yes & yes \\
# Freeze Dance Game! & yes & yes & yes & yes \\
# Rye Bread Order & yes & yes & yes & yes \\
# Tower of London! & yes & no & yes & no \\
# Holiday Movies & no & yes & yes & no \\
# \bottomrule
# \end{tabularx}
