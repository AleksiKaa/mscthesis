# %%
import pandas as pd

# %%
df = pd.read_csv(r"../../outputs/results/generate_judge_result_16337590.csv", sep=";")

# %%
eval_cols = df.columns[11:14]

df[eval_cols]
# Out:
#                        title  \
# 0             Berry Picking!
# 1           Pass the Parcel!
# 2           Pass the Parcel!
# 3  Holiday Parade Attendance
#
#                                   problemDescription  \
# 0  Write a program that asks the user for their f...
# 1  Write a program that asks the user for their n...
# 2  Write a program that asks the user for their n...
# 3  Write a program that asks the user if they wil...
#
#                                      exampleSolution  \
# 0  {'code': "import 'dart:io';main() {  print('Wh...
# 1  {'code': "import 'dart:io';main() {  print('Wh...
# 2  {'code': "import 'dart:io';main() {  print('Wh...
# 3  {'code': "import 'dart:io';  main() {   print(...
#
#                                   starterCode  \
# 0      {'code': "import 'dart:io';main() {}"}
# 1      {'code': "import 'dart:io';main() {}"}
# 2      {'code': "import 'dart:io';main() {}"}
# 3  {'code': "import 'dart:io';  main() {  }"}
#
#                                                tests               theme  \
# 0  {'testCode': "import 'package:test/test.dart';...  outdoor activities
# 1  {'testCode': "import 'package:test/test.dart';...         party games
# 2  {'testCode': "import 'package:test/test.dart';...         party games
# 3  {'testCode': "import 'package:test/test.dart';...           Christmas
#
#                        topic         concept difficulty            id  ...  \
# 0              berry picking      user input     normal  3.688261e+14  ...
# 1            Pass the Parcel      user input   advanced  9.796044e+14  ...
# 2            Pass the Parcel  program output     normal  6.068320e+14  ...
# 3  attending holiday parades  program output     normal -8.374976e+13  ...
#
#   The exercise description matched the selected concept (Yes/No)  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
#
#   Included concepts that were too advanced (Yes/No)\n  \
# 0                                                 no
# 1                                                 no
# 2                                                 no
# 3                                                yes
#
#   The exercise difficulty matched the selected difficulty (Too easy/Okay/Too difficult)  \
# 0                                               okay
# 1                                           too easy
# 2                                      too difficult
# 3                                      too difficult
#
#   Shallow vs deep personalization (Deep/Shallow/Unsure) Open field   \
# 0                                            shallow            NaN
# 1                                            shallow            NaN
# 2                                             unsure            NaN
# 3                                             unsure            NaN
#
#                                               prompt ThemeCorrect  \
# 0  You are evaluating a programming exercise.\n\n...          yes
# 1  You are evaluating a programming exercise.\n\n...           no
# 2  You are evaluating a programming exercise.\n\n...          yes
# 3  You are evaluating a programming exercise.\n\n...          yes
#
#    TopicCorrect ConceptCorrect  \
# 0           yes            yes
# 1            no            yes
# 2           yes            yes
# 3           yes            yes
#
#                                          Explanation
# 0  The exercise is about asking the user for thei...
# 1  The exercise is actually about getting user in...
# 2  This exercise is about creating a simple inter...
# 3  The exercise is about asking the user if they ...
#
# [4 rows x 23 columns]

# %%
for idx, row in df.iterrows():
    print("Theme: ", row["ThemeCorrect"])
    print("Topic: ", row["TopicCorrect"])
    print("Concept: ", row["ConceptCorrect"])
    print("Reasoning: ", row["Explanation"])
    print("")
# Out:
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  The exercise is about asking the user for their favorite type of berry and then printing a message with the user's input. This matches the theme of outdoor activities, as berry picking is often done outdoors. It also matches the topic of berry picking, as it specifically asks about the user's favorite type of berry. Finally, it matches the programming concept of user input, as it uses the stdin.readLineSync() function to get input from the user. Overall, the exercise description is clear and well-matched to the intended theme, topic, and programming concept.
#
# Theme:  no
# Topic:  no
# Concept:  yes
# Reasoning:  The exercise is actually about getting user input and printing a personalized message. The exercise description does not match the selected theme of 'party games' or the topic of 'Pass the Parcel', as it does not involve any game-like functionality. However, it does match the selected programming concept of 'user input', as it involves getting input from the user and using it to print a message.
#
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  This exercise is about creating a simple interactive program that takes user input and prints a personalized message, which matches the theme of party games and the topic of Pass the Parcel. The program output is the main focus of the exercise, demonstrating the programming concept of output. The exercise description clearly explains what the program should do, and the example solution provided is a correct implementation of the described behavior.
#
# Theme:  yes
# Topic:  yes
# Concept:  yes
# Reasoning:  The exercise is about asking the user if they will attend the holiday parade and printing a message based on their response. The theme is Christmas, which matches the holiday parade context. The topic is attending holiday parades, which is also a match. The programming concept is program output, as the exercise involves printing messages to the user based on their input. Overall, the exercise description matches the selected theme, topic, and programming concept.
