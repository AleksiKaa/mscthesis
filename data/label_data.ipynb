# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Definitions
filename = r"int_agreement (cleaned).xlsx"
sheet_names = ["Arto", "Evanfiya", "James", "Juho", "Sami"]


def load_spreadsheet(filepath):
    sheets = pd.read_excel(filename, sheet_name=sheet_names)
    return sheets

def label_data(df, slicer, predicate, label="label", use_all=True):
    reducer = all if use_all else any
    labels = (df.iloc[slicer] # Pick relevant data
        .apply(predicate) # Apply predicate
        .apply(reducer, axis=1) # Reduce to single boolean column
        .apply(lambda label : "yes" if label else "no")) # Convert back to yes/no
    labels.name = label
    return labels

# Filters
is_null = lambda x: x.isnull()

# %%
sheets = load_spreadsheet(filename)
df = pd.concat(sheets.values(), axis=0).dropna(axis=0, subset="title")
#df.reset_index(inplace=True, drop=True)

# %%
slice_s = 11
slice_e = 14
eval_cols = df.columns[slice_s:slice_e]

yes_df = df[eval_cols].eq("yes").astype(int).groupby(df.index).sum().eq(5).map(lambda x: "yes" if x else "no")

df = df.drop_duplicates("title")
df[eval_cols] = yes_df[eval_cols]

df.head()
# Out:
#                 title                                 problemDescription  \
# 0   Wildlife Spotting  Write a program that asks the user for their f...
# 1  Freeze Dance Game!  Write a program that asks the user if they wan...
# 2     Rye Bread Order  Write a program that asks the user for their n...
# 3    Tower of London!  Write a program that asks the user for their f...
# 4      Holiday Movies  Write a program that asks the user for their f...
#
#                                      exampleSolution  \
# 0  {'code': "import 'dart:io';main() {  print('Wh...
# 1  {'code': "import 'dart:io';main() {  print('Do...
# 2  {'code': "import 'dart:io';main() {  print('Wh...
# 3  {'code': "import 'dart:io';main() {  print('Wh...
# 4  {'code': "import 'dart:io';main() {  print('Wh...
#
#                               starterCode  \
# 0  {'code': "import 'dart:io';main() {}"}
# 1  {'code': "import 'dart:io';main() {}"}
# 2  {'code': "import 'dart:io';main() {}"}
# 3  {'code': "import 'dart:io';main() {}"}
# 4  {'code': "import 'dart:io';main() {}"}
#
#                                                tests                 theme  \
# 0  {'testCode': "import 'package:test/test.dart';...    outdoor activities
# 1  {'testCode': "import 'package:test/test.dart';...           party games
# 2  {'testCode': "import 'package:test/test.dart';...                  food
# 3  {'testCode': "import 'package:test/test.dart';...  historical landmarks
# 4  {'testCode': "import 'package:test/test.dart';...             Christmas
#
#                      topic         concept difficulty            id  \
# 0        wildlife spotting      user input   advanced -3.586648e+13
# 1             Freeze Dance      user input     normal -2.992254e+13
# 2                Rye bread      user input   advanced  1.702298e+14
# 3          Tower of London      user input     normal  6.744981e+14
# 4  watching holiday movies  program output     normal -4.978922e+13
#
#   The exercise description was clear (Yes/Partially/No)  \
# 0                                          partially
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   The exercise description matched the selected theme (Yes/Partially/No)  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                 no
#
#   The exercise description matched the selected topic (Yes/Partially/No)  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                 no
# 4                                                yes
#
#   The exercise description matched the selected concept (Yes/No)  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
# 3                                                yes
# 4                                                yes
#
#   Included concepts that were too advanced (Yes/No)\n  \
# 0                                                 no
# 1                                                yes
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#   The exercise difficulty matched the selected difficulty (Too easy/Okay/Too difficult)  \
# 0                                               okay
# 1                                      too difficult
# 2                                               okay
# 3                                               okay
# 4                                               okay
#
#   Shallow vs deep personalization (Deep/Shallow/Unsure)  \
# 0                                            shallow
# 1                                            shallow
# 2                                             unsure
# 3                                            shallow
# 4                                            shallow
#
#                                          Open field
# 0  The handout had "I hope you see a/an animal", ...
# 1                Requires knowledge of conditionals.
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
slice_obj = np.s_[:, slice_s:slice_e]
pred = lambda s: s.str.lower() == "yes"
label = "All metrics are correct (Yes/No)"

result2 = pd.concat([df, label_data(df, slice_obj, pred, label)], axis=1)

# %%
stats = [
    *range(slice_s, slice_e),
    len(result2.columns) - 1
]

count_yes = (result2.iloc[:, stats] == "yes").sum()
count_no = len(result2) - count_yes
percentages = count_yes / len(result2)

pd.DataFrame(data={"Correct (Yes)": count_yes, "Incorrect (Partially/No)": count_no, "Percentage of correct": percentages})

#df[label].where(lambda x : x == "yes").dropna().count() / len(df[label])
# Out:
#                                                     Correct (Yes)  \
# The exercise description matched the selected t...             31
# The exercise description matched the selected t...             28
# The exercise description matched the selected c...             29
# All metrics are correct (Yes/No)                               24
#
#                                                     Incorrect (Partially/No)  \
# The exercise description matched the selected t...                         2
# The exercise description matched the selected t...                         5
# The exercise description matched the selected c...                         4
# All metrics are correct (Yes/No)                                           9
#
#                                                     Percentage of correct
# The exercise description matched the selected t...               0.939394
# The exercise description matched the selected t...               0.848485
# The exercise description matched the selected c...               0.878788
# All metrics are correct (Yes/No)                                 0.727273

# %%
result2.to_csv("out.csv", sep=";", columns=["title", "topic", "theme", "concept", "problemDescription", "exampleSolution", *eval_cols, label], index=False)
